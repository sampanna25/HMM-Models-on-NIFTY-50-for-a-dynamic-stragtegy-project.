# %%
# !pip install hmmlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.2/217.2 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29103 sha256=5b0db3007d3d2cd29ae6bd6bf9491fb83fbf78db7e338455dc57013b4c8943a4
#   Stored in directory: /root/.cache/pip/wheels/6a/76/03/7f785aaa50b9c6ec7e3fd105a62c1b2c45a034512d51e024a9
# Successfully built ta
# ...

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as pdr
import datetime as dt
from hmmlearn.hmm import GaussianHMM
import yfinance as yf

# %%
end_date = dt.date.today()
start_date = end_date - dt.timedelta(days = 6300)
ticker='^NSEI'

# %%
data= yf.download(ticker,start_date, end_date)
#data = pdr.get_data_yahoo(ticker, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-09-17   4518.450195   4549.049805   4482.850098   4494.649902
# 2007-09-18   4494.100098   4551.799805   4481.549805   4546.200195
# 2007-09-19   4550.250000   4739.000000   4550.250000   4732.350098
# 2007-09-20   4734.850098   4760.850098   4721.149902   4747.549805
# 2007-09-21   4752.950195   4855.700195   4733.700195   4837.549805
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume
# Date
# 2007-09-17   4494.649902       0
# 2007-09-18   4546.200195       0
# 2007-09-19   4732.350098       0
# ...

# %%
data['Volatility'] = data['Close'].rolling(20).std()

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-10-15   5428.350098   5682.649902   5419.899902   5670.399902
# 2007-10-16   5670.649902   5708.350098   5578.450195   5668.049805
# 2007-10-17   5658.899902   5658.899902   5107.299805   5559.299805
# 2007-10-18   5551.100098   5736.799805   5269.649902   5351.000000
# 2007-10-19   5360.350098   5390.850098   5101.750000   5215.299805
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility
# Date
# 2007-10-15   5670.399902       0  315.391206
# 2007-10-16   5668.049805       0  312.410514
# ...

# %%
X_train = data.loc[:'2019', ['Volatility']].values
X_test = data.loc['2020':, ['Volatility']].values

# %%
X_train
# Out:
# array([[315.39120642],
#        [312.41051428],
#        [295.13626903],
#        ...,
#        [131.37512351],
#        [136.6822709 ],
#        [137.23755166]])

# %%
hmm_model1 = GaussianHMM(n_components = 2, covariance_type="full", n_iter=1000).fit(X_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
for i in range(hmm_model1.n_components):
    print("{0}th hidden state".format(i))
    print("mean = ", hmm_model1.means_[i])
# Out:
# 0th hidden state
# mean =  [96.54321125]
# 1th hidden state
# mean =  [198.19559476]

# %%
data.loc[:'2019','Regime'] = hmm_model1.predict(X_train)
data.loc['2020':,'Regime'] = hmm_model1.predict(X_test)

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-10-15   5428.350098   5682.649902   5419.899902   5670.399902
# 2007-10-16   5670.649902   5708.350098   5578.450195   5668.049805
# 2007-10-17   5658.899902   5658.899902   5107.299805   5559.299805
# 2007-10-18   5551.100098   5736.799805   5269.649902   5351.000000
# 2007-10-19   5360.350098   5390.850098   5101.750000   5215.299805
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime
# Date
# 2007-10-15   5670.399902       0  315.391206     1.0
# ...

# %%
data['SMA'] = data['Close'].rolling(50).mean()
data['Diff_SMA'] = data['Close'].rolling(12).mean() - data['Close'].rolling(24).mean()

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA    Diff_SMA
# Date
# ...

# %%
Y_train = data.loc[:'2019', ['Diff_SMA']].values
Y_test = data.loc['2020':, ['Diff_SMA']].values

# %%
hmm_model2 = GaussianHMM(n_components = 2, covariance_type="full", n_iter=1000).fit(Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
for i in range(hmm_model2.n_components):
    print("{0}th hidden state".format(i))
    print("mean = ", hmm_model2.means_[i])
# Out:
# 0th hidden state
# mean =  [12.6881566]
# 1th hidden state
# mean =  [12.65420749]

# %%
data.loc[:'2019','Trend'] = hmm_model2.predict(Y_train)
data.loc['2020':,'Trend'] = hmm_model2.predict(Y_test)

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
plt.figure(figsize = (16,12))
plt.plot(data.index, data['SMA'], label = 'SMA')
plt.scatter(data[data['Trend']==1].index, data[data['Trend'] == 1]['Close'], s = 4, label = 'Bearish', c = 'red')
plt.scatter(data[data['Trend']==0].index, data[data['Trend'] == 0]['Close'], s = 4, label = 'Bullish', c = 'green')
plt.legend()

# %%
plt.figure(figsize = (20,12))
plt.scatter(data[data['Regime'] == 1].index, data[data['Regime'] == 1]['Close'], s = 4, label = 'High_Var')
plt.scatter(data[data['Regime'] == 0].index, data[data['Regime'] == 0]['Close'], s = 4, label = 'Low_Var')
plt.legend()

# %%
plt.figure(figsize = (20,12))
plt.scatter(data[(data['Regime'] == 1) & (data['Trend'] == 0)].index, data[(data['Regime'] == 1) & (data['Trend'] == 0)]['Close'], s = 4, label = 'Bullish_High_Var')
plt.scatter(data[(data['Regime'] == 1) & (data['Trend'] == 1)].index, data[(data['Regime'] == 1) & (data['Trend'] == 1)]['Close'], s = 4, label = 'Bearish_High_Var')
plt.scatter(data[(data['Regime'] == 0) & (data['Trend'] == 0)].index, data[(data['Regime'] == 0) & (data['Trend'] == 0)]['Close'], s = 4, label = 'Bullish_Low_Var')
plt.scatter(data[(data['Regime'] == 0) & (data['Trend'] == 1)].index, data[(data['Regime'] == 0) & (data['Trend'] == 1)]['Close'], s = 4, label = 'Bearish_Low_Var')
plt.legend()

# %%
from ta.volatility import BollingerBands
indicator_bb = BollingerBands(close=data["Close"], window=20, window_dev=1.5)
#data['bb_bbm_1.5'] = indicator_bb.bollinger_mavg()
#data['bb_bbh_1.5'] = indicator_bb.bollinger_hband()
#data['bb_bbl_1.5'] = indicator_bb.bollinger_lband()

# Add Bollinger Band high indicator
data['bb_bbhi_1.5'] = indicator_bb.bollinger_hband_indicator()

# Add Bollinger Band low indicator
data['bb_bbli_1.5'] = indicator_bb.bollinger_lband_indicator()

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
from ta.momentum import RSIIndicator
indicator_rsi=RSIIndicator(close=data["Close"], window=14)
data['rsi']=indicator_rsi.rsi()

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
data['SMA_10']=data['Close'].rolling(10).mean()
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
indicator_bb = BollingerBands(close=data["Close"], window=20, window_dev=1)
#data['bb_bbm_1.5'] = indicator_bb.bollinger_mavg()
#data['bb_bbh_1.5'] = indicator_bb.bollinger_hband()
#data['bb_bbl_1.5'] = indicator_bb.bollinger_lband()

# Add Bollinger Band high indicator
data['bb_bbhi_1'] = indicator_bb.bollinger_hband_indicator()

# Add Bollinger Band low indicator
data['bb_bbli_1'] = indicator_bb.bollinger_lband_indicator()

data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
from ta.volatility import AverageTrueRange
indicator_atr=AverageTrueRange(high=data["High"], low=data["Low"], close=data["Close"], window=14)
data["ATR"]=indicator_atr.average_true_range()

data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2007-12-26   5988.450195   6085.250000   5988.450195   6070.750000
# 2007-12-27   6069.000000   6110.850098   6060.200195   6081.500000
# 2007-12-28   6079.549805   6098.600098   6021.899902   6079.700195
# 2007-12-31   6095.000000   6167.750000   6095.000000   6138.600098
# 2008-01-01   6136.750000   6165.350098   6109.850098   6144.350098
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2007-12-26   6070.750000       0  160.915558     1.0   5767.558984
# ...

# %%
price_min = data.Close.min()
price_max = data.Close.max()
diff = price_max - price_min
level1 = price_max - 0.236 * diff
level2 = price_max - 0.382 * diff
level3 = price_max - 0.618 * diff

# %%
data=data.dropna()
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-01-14   6208.799805   6244.149902   6172.000000   6206.799805
# 2008-01-15   6226.350098   6260.450195   6053.299805   6074.250000
# 2008-01-16   6065.000000   6065.000000   5825.750000   5935.750000
# 2008-01-17   5937.950195   6013.149902   5880.299805   5913.200195
# 2008-01-18   5907.750000   5908.750000   5677.000000   5705.299805
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2008-01-14   6206.799805       0  184.025544     1.0   5925.854004
# ...

# %%
#short signal
data['Sell_Signal']= np.where(data['bb_bbhi_1.5']==1.0, 1, 0)
data['Sell_Signal']= np.where(data['rsi']>65.0, 1, data['Sell_Signal'])
#data['Sell_Signal']= np.where(data['Close']>data['SMA_10'], True, False)
#data['Sell_Signal']= np.where(data['Close']>level3, True, False)

#exit short signal
#data['Buy_Signal']= np.where(data['bb_bbli_1']==0, True, False)
data['Buy_Signal']= np.where(data['rsi']<25.0, 1, 0)
data['Buy_Signal']= np.where(data['Close']>data['SMA_10'], 1, data['Buy_Signal'])
#data['Buy_Signal']= np.where(data['Close']<data['SMA_10']-5*data['ATR'], True, False)
#data['Buy_Signal']= np.where(data['Close']>data['SMA_10']+5*data['ATR'], True, False)
# Out:
# <ipython-input-68-df3a66bae7a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sell_Signal']= np.where(data['bb_bbhi_1.5']==1.0, 1, 0)
# <ipython-input-68-df3a66bae7a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sell_Signal']= np.where(data['rsi']>65.0, 1, data['Sell_Signal'])
# <ipython-input-68-df3a66bae7a0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2008-01-14   6208.799805   6244.149902   6172.000000   6206.799805
# 2008-01-15   6226.350098   6260.450195   6053.299805   6074.250000
# 2008-01-16   6065.000000   6065.000000   5825.750000   5935.750000
# 2008-01-17   5937.950195   6013.149902   5880.299805   5913.200195
# 2008-01-18   5907.750000   5908.750000   5677.000000   5705.299805
# ...                  ...           ...           ...           ...
# 2023-04-06  17533.849609  17638.699219  17502.849609  17599.150391
# 2023-04-10  17634.900391  17694.099609  17597.949219  17624.050781
# 2023-04-11  17704.800781  17748.750000  17655.150391  17722.300781
# 2023-04-12  17759.550781  17825.750000  17717.250000  17812.400391
# 2023-04-13  17807.300781  17842.150391  17729.650391  17828.000000
#
#                Adj Close  Volume  Volatility  Regime           SMA  \
# Date
# 2008-01-14   6206.799805       0  184.025544     1.0   5925.854004
# ...

# %%
Buying_dates=[]
Selling_dates=[]

for i in range (len(data)):
  if data['Sell_Signal'].iloc[i]==1:
    if (i+1)<len(data):
      Selling_dates.append(data.iloc[i+1].name)
    else:
       Selling_dates.append(data.iloc[i].name)
    for j in range (1, len(data)-i):
      if data['Buy_Signal'].iloc[i]==1:
        if (i+j+1)<len(data):
          Buying_dates.append(data.iloc[i+j+1].name)
        else:
          Buying_dates.append(data.iloc[i+j].name)
        break
      elif j==(len(data)-i-1):
        Buying_dates.append(data.iloc[i+j].name)

# %%
len(Buying_dates)
#Buying_dates
# Out:
# 985

# %%
Selling_dates
# Out:
# [Timestamp('2008-04-21 00:00:00'),
#  Timestamp('2008-04-22 00:00:00'),
#  Timestamp('2008-04-23 00:00:00'),
#  Timestamp('2008-04-24 00:00:00'),
#  Timestamp('2008-04-28 00:00:00'),
#  Timestamp('2008-04-29 00:00:00'),
#  Timestamp('2008-04-30 00:00:00'),
#  Timestamp('2008-05-02 00:00:00'),
#  Timestamp('2008-05-05 00:00:00'),
#  Timestamp('2008-07-24 00:00:00'),
#  Timestamp('2008-07-25 00:00:00'),
#  Timestamp('2008-12-12 00:00:00'),
#  Timestamp('2008-12-15 00:00:00'),
#  Timestamp('2008-12-16 00:00:00'),
#  Timestamp('2008-12-17 00:00:00'),
#  Timestamp('2008-12-19 00:00:00'),
#  Timestamp('2008-12-22 00:00:00'),
#  Timestamp('2009-01-06 00:00:00'),
#  Timestamp('2009-02-10 00:00:00'),
#  Timestamp('2009-02-11 00:00:00'),
#  Timestamp('2009-02-12 00:00:00'),
#  Timestamp('2009-02-16 00:00:00'),
#  Timestamp('2009-03-24 00:00:00'),
#  Timestamp('2009-03-25 00:00:00'),
#  Timestamp('2009-03-26 00:00:00'),
#  Timestamp('2009-03-27 00:00:00'),
#  Timestamp('2009-03-30 00:00:00'),
# ...

# %%
len(Selling_dates)
#Selling_dates
# Out:
# 986

# %%
Selling_dates.pop()
# Out:
# Timestamp('2023-04-13 00:00:00')

# %%
frame=pd.DataFrame({'Selling_dates':Selling_dates, 'Buying_dates':Buying_dates})

# %%
frame.head(20)
# Out:
#    Selling_dates Buying_dates
# 0     2008-04-21   2008-04-22
# 1     2008-04-22   2008-04-23
# 2     2008-04-23   2008-04-24
# 3     2008-04-24   2008-04-25
# 4     2008-04-28   2008-04-29
# 5     2008-04-29   2008-04-30
# 6     2008-04-30   2008-05-02
# 7     2008-05-02   2008-05-05
# 8     2008-05-05   2008-05-06
# 9     2008-07-24   2008-07-25
# 10    2008-07-25   2008-07-28
# 11    2008-12-12   2008-12-15
# 12    2008-12-15   2008-12-16
# 13    2008-12-16   2008-12-17
# 14    2008-12-17   2008-12-18
# 15    2008-12-19   2008-12-22
# 16    2008-12-22   2008-12-23
# 17    2009-01-06   2009-01-07
# 18    2009-02-10   2009-02-11
# 19    2009-02-11   2009-02-12

# %%
actualtrades= frame[frame.Selling_dates>frame.Buying_dates.shift(1)]

# %%
actualtrades
# Out:
#     Selling_dates Buying_dates
# 4      2008-04-28   2008-04-29
# 9      2008-07-24   2008-07-25
# 11     2008-12-12   2008-12-15
# 15     2008-12-19   2008-12-22
# 17     2009-01-06   2009-01-07
# ..            ...          ...
# 952    2022-09-13   2022-09-14
# 955    2022-10-21   2022-10-24
# 968    2022-11-14   2022-11-15
# 973    2022-11-25   2022-11-28
# 981    2023-04-10   2023-04-11
#
# [200 rows x 2 columns]

# %%
actualtrades= frame[:1].append(actualtrades)
# Out:
# <ipython-input-79-7fc6bacd10da>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   actualtrades= frame[:1].append(actualtrades)

# %%
profits= \
data.loc[actualtrades.Buying_dates].Open.values - data.loc[actualtrades.Selling_dates].Open.values

# %%
profits
# Out:
# array([ 8.11499023e+01, -2.01000977e+01, -3.53500977e+01,  2.54980469e+00,
#         1.42500000e+01, -8.69995117e+00,  1.33000488e+01, -9.43999023e+01,
#         1.50000000e+01,  4.40000000e+01,  5.76999512e+01,  1.85800049e+02,
#        -3.68500977e+01, -6.20019531e+00, -3.22001953e+01,  4.38500977e+01,
#        -2.52998047e+01, -1.02450195e+02,  2.20498047e+01, -2.20000000e+01,
#         6.38999023e+01, -9.89990234e+00, -3.52500000e+01,  8.00000000e+00,
#         1.00000000e+00,  8.11503906e+01,  3.40996094e+01,  3.52500000e+01,
#         7.82500000e+01, -1.32998047e+01,  2.37500000e+01,  1.79501953e+01,
#         4.64990234e+00, -2.18999023e+01, -2.60996094e+01,  6.25498047e+01,
#         2.83500977e+01, -5.83999023e+01, -5.42500000e+01,  4.27500000e+01,
#         4.12500000e+01, -7.43999023e+01,  3.58002930e+01, -2.62001953e+01,
#        -8.66000977e+01,  1.70000000e+01, -2.21997070e+01,  6.05000000e+01,
# ...

# %%
win_ratio = len([i for i in profits if i>0])/len(profits) #win ratio
print(win_ratio)
# Out:
# 0.5422885572139303

# %%
relprofits= \
(data.loc[actualtrades.Buying_dates].Open.values - data.loc[actualtrades.Selling_dates].Open.values)/data.loc[actualtrades.Selling_dates].Open.values

# %%
relprofits
# Out:
# array([ 1.63744030e-02, -3.93155944e-03, -7.89734509e-03,  8.74613546e-04,
#         4.65230167e-03, -2.78710593e-03,  4.55527933e-03, -3.20189612e-02,
#         5.13030979e-03,  1.37014024e-02,  1.68535897e-02,  5.34107717e-02,
#        -1.00443196e-02, -1.43358768e-03, -7.15321455e-03,  9.69105807e-03,
#        -5.37578851e-03, -2.18241489e-02,  4.61018101e-03, -4.55453529e-03,
#         1.30550506e-02, -1.93412250e-03, -6.84778504e-03,  1.54417797e-03,
#         1.89496228e-04,  1.61789533e-02,  6.55957220e-03,  6.74602440e-03,
#         1.47881471e-02, -2.48401799e-03,  4.56616632e-03,  3.35376623e-03,
#         8.54463042e-04, -4.00352874e-03, -4.75680001e-03,  1.14178441e-02,
#         5.08439860e-03, -9.36751587e-03, -8.56319798e-03,  7.05172075e-03,
#         7.30702803e-03, -1.26128251e-02,  6.47394955e-03, -4.59189332e-03,
#        -1.51012004e-02,  3.18238835e-03, -4.56488232e-03,  1.24896780e-02,
# ...

# %%
relprofits.mean()*100 #avg profit per trade
# Out:
# 0.9326021702689032

# %%
arr= 100000 * (relprofits +1 ).cumprod()
final_val= arr[len(arr)-1]
print(final_val)
#final amont if started with Rs. 1 lakh
# Out:
# 310752.1362684517

# %%
#CAGR
cagr= (((final_val/100000.0)**(365.0/5688))-1)*100
cagr
# Out:
# 7.547000979660634

# %%
#maximum drawdown
max_draw=min(relprofits)
(max_draw*-1)*100
# Out:
# 5.4403011196013145
